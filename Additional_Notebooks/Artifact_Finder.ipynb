# %%
input_folder = "input_imgs"

# %%
# !git clone https://github.com/ming053l/DRCT.git
# !pip install -r DRCT/requirements.txt
# !pip install tqdm

# %%
import os
import re
import fileinput
from PIL import Image
import numpy as np
import pandas as pd
import basicsr
import sys


# Directory Setup
output_folder = 'Output_KK'
os.makedirs('Output_data', exist_ok=True)
os.makedirs('Stacked_data', exist_ok=True)

print("Directories created:")
print(os.listdir('.'))


# Function to patch basicsr import issue
def patch_basicsr_import():
    """
    Patch the basicsr 'degradations.py' file to fix import issues.
    """
    try:
        import basicsr
        basicsr_path = os.path.dirname(basicsr.__file__)
        degradations_path = os.path.join(basicsr_path, 'data', 'degradations.py')

        if not os.path.exists(degradations_path):
            print(f"Could not find degradations.py at {degradations_path}")
            return False

        # Create backup if not already created
        backup_path = degradations_path + '.backup'
        if not os.path.exists(backup_path):
            with open(degradations_path, 'r') as src, open(backup_path, 'w') as dst:
                dst.write(src.read())

        # Replace problematic import
        old_import = "from torchvision.transforms.functional_tensor import rgb_to_grayscale"
        new_import = "from torchvision.transforms.functional import rgb_to_grayscale"

        with fileinput.FileInput(degradations_path, inplace=True, backup='.bak') as file:
            for line in file:
                print(line.replace(old_import, new_import), end='')

        print(f"Successfully patched {degradations_path}")
        return True

    except ImportError:
        print("BasicSR package not found. Please ensure it's installed.")
        return False
    except Exception as e:
        print(f"An error occurred: {str(e)}")
        return False


# Function to patch inference file strict=True issue
def patch_inference_file(file_path="DRCT/inference.py"):
    """
    Modify the inference.py file to replace 'strict=True' with 'strict=False'.
    """
    try:
        # Create backup if not already created
        backup_path = file_path + '.backup'
        if not os.path.exists(backup_path):
            with open(file_path, 'r') as src, open(backup_path, 'w') as dst:
                dst.write(src.read())

        # Replace strict=True with strict=False
        pattern = r'(model\.load_state_dict\(.*strict=)True(\).*)'
        with open(file_path, 'r') as file:
            content = file.read()

        modified_content = re.sub(pattern, r'\1False\2', content)

        with open(file_path, 'w') as file:
            file.write(modified_content)

        print(f"Successfully modified {file_path}")
        print("Changed strict=True to strict=False")
        return True

    except FileNotFoundError:
        print(f"Could not find file at {file_path}")
        return False
    except Exception as e:
        print(f"An error occurred: {str(e)}")
        return False


# Execute patch functions
patch_basicsr_import()
patch_inference_file()

# Image Stacking
os.makedirs(output_folder, exist_ok=True)

for filename in os.listdir(input_folder):
    if filename.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff', '.webp')):
        image_path = os.path.join(input_folder, filename)
        image = Image.open(image_path)

        # Resize the image to 32x32
        image = image.resize((32, 32))

        # Create the stacked image (64x64)
        stacked_image = Image.new('RGB', (64, 64))
        stacked_image.paste(image, (0, 0))        # Top-left
        stacked_image.paste(image, (32, 0))      # Top-right
        stacked_image.paste(image, (0, 32))      # Bottom-left
        stacked_image.paste(image, (32, 32))     # Bottom-right

        # Save the stacked image
        base_name, ext = os.path.splitext(filename)
        output_path = os.path.join(output_folder, f"{base_name}_resized{ext}")
        stacked_image.save(output_path)
        print(f"Processed and saved: {output_path}")

print("All eligible images have been processed.")


# Run inference script

# !python DRCT/inference.py --model_path Model_weights/net_g_latest.pth --input Output_KK --output Output_data --scale 4

# Cropping Images
input_folder1 = "Output_data"
output_folder = "very_big_img"
os.makedirs(output_folder, exist_ok=True)

for filename in os.listdir(input_folder1):
    input_path = os.path.join(input_folder1, filename)

    if os.path.isfile(input_path) and filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
        with Image.open(input_path) as img:
            # Define the crop box for the top-left quarter
            width, height = img.size
            crop_box = (0, 0, width // 2, height // 2)
            cropped_img = img.crop(crop_box)

            # Save the cropped image
            output_path = os.path.join(output_folder, filename)
            cropped_img.save(output_path)

print("Cropping complete! Final images are saved in:", output_folder)
# Out:
# Directories created:
# ['.config', '.local', '.ipython', '.jupyter', '.ipynb_checkpoints', 'Artifact_detection.ipynb', 'Task_2_Pipeline_README.md', 'input_imgs', '.cache', 'Model_weights', 'Artifact_descriptions', '.nv', 'DRCT', 'Output_data', 'Stacked_data']
# Successfully patched /root/miniconda3/envs/py3.10/lib/python3.10/site-packages/basicsr/data/degradations.py
# Successfully modified DRCT/inference.py
# Changed strict=True to strict=False
# Processed and saved: Output_KK/1_resized.png
# Processed and saved: Output_KK/9_resized.png
# Processed and saved: Output_KK/7_resized.png
# Processed and saved: Output_KK/3_resized.png
# Processed and saved: Output_KK/4_resized.png
# Processed and saved: Output_KK/8_resized.png
# Processed and saved: Output_KK/10_resized.png
# Processed and saved: Output_KK/2_resized.png
# Processed and saved: Output_KK/5_resized.png
# Processed and saved: Output_KK/6_resized.png
# All eligible images have been processed.
# /root/miniconda3/envs/py3.10/lib/python3.10/site-packages/torch/functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3609.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /home/DRCT/inference.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(args.model_path)['params'], strict=False)
# DRCT(
#   (conv_first): Conv2d(3, 180, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (patch_embed): PatchEmbed(
#     (norm): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#   )
#   (patch_unembed): PatchUnEmbed()
#   (pos_drop): Dropout(p=0.0, inplace=False)
#   (layers): ModuleList(
#     (0): RDG(
#       (swin1): SwinTransformerBlock(
#         dim=180, input_resolution=(64, 64), num_heads=6, window_size=16, shift_size=0, mlp_ratio=2
#         (norm1): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#         (attn): WindowAttention(
#           dim=180, window_size=(16, 16), num_heads=6
#           (qkv): Linear(in_features=180, out_features=540, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=180, out_features=180, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#           (softmax): Softmax(dim=-1)
#         )
#         (drop_path): Identity()
#         (norm2): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=180, out_features=360, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=360, out_features=180, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (adjust1): Conv2d(180, 32, kernel_size=(1, 1), stride=(1, 1))
#       (swin2): SwinTransformerBlock(
#         dim=212, input_resolution=(64, 64), num_heads=4, window_size=16, shift_size=8, mlp_ratio=2
#         (norm1): LayerNorm((212,), eps=1e-05, elementwise_affine=True)
#         (attn): WindowAttention(
#           dim=212, window_size=(16, 16), num_heads=4
#           (qkv): Linear(in_features=212, out_features=636, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=212, out_features=212, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#           (softmax): Softmax(dim=-1)
#         )
#         (drop_path): Identity()
#         (norm2): LayerNorm((212,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=212, out_features=424, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=424, out_features=212, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (adjust2): Conv2d(212, 32, kernel_size=(1, 1), stride=(1, 1))
#       (swin3): SwinTransformerBlock(
#         dim=244, input_resolution=(64, 64), num_heads=2, window_size=16, shift_size=0, mlp_ratio=2
#         (norm1): LayerNorm((244,), eps=1e-05, elementwise_affine=True)
#         (attn): WindowAttention(
#           dim=244, window_size=(16, 16), num_heads=2
#           (qkv): Linear(in_features=244, out_features=732, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=244, out_features=244, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#           (softmax): Softmax(dim=-1)
#         )
#         (drop_path): Identity()
#         (norm2): LayerNorm((244,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=244, out_features=488, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=488, out_features=244, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (adjust3): Conv2d(244, 32, kernel_size=(1, 1), stride=(1, 1))
#       (swin4): SwinTransformerBlock(
#         dim=276, input_resolution=(64, 64), num_heads=6, window_size=16, shift_size=8, mlp_ratio=1
#         (norm1): LayerNorm((276,), eps=1e-05, elementwise_affine=True)
#         (attn): WindowAttention(
#           dim=276, window_size=(16, 16), num_heads=6
#           (qkv): Linear(in_features=276, out_features=828, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=276, out_features=276, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#           (softmax): Softmax(dim=-1)
#         )
#         (drop_path): Identity()
#         (norm2): LayerNorm((276,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=276, out_features=276, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=276, out_features=276, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (adjust4): Conv2d(276, 32, kernel_size=(1, 1), stride=(1, 1))
#       (swin5): SwinTransformerBlock(
#         dim=308, input_resolution=(64, 64), num_heads=4, window_size=16, shift_size=0, mlp_ratio=1
#         (norm1): LayerNorm((308,), eps=1e-05, elementwise_affine=True)
#         (attn): WindowAttention(
#           dim=308, window_size=(16, 16), num_heads=4
#           (qkv): Linear(in_features=308, out_features=924, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=308, out_features=308, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#           (softmax): Softmax(dim=-1)
#         )
#         (drop_path): Identity()
#         (norm2): LayerNorm((308,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=308, out_features=308, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=308, out_features=308, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (adjust5): Conv2d(308, 180, kernel_size=(1, 1), stride=(1, 1))
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (pe): PatchEmbed()
#       (pue): PatchUnEmbed()
#     )
#     (1-11): 11 x RDG(
#       (swin1): SwinTransformerBlock(
#         dim=180, input_resolution=(64, 64), num_heads=6, window_size=16, shift_size=0, mlp_ratio=2
#         (norm1): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#         (attn): WindowAttention(
#           dim=180, window_size=(16, 16), num_heads=6
#           (qkv): Linear(in_features=180, out_features=540, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=180, out_features=180, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#           (softmax): Softmax(dim=-1)
#         )
#         (drop_path): DropPath()
#         (norm2): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=180, out_features=360, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=360, out_features=180, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (adjust1): Conv2d(180, 32, kernel_size=(1, 1), stride=(1, 1))
#       (swin2): SwinTransformerBlock(
#         dim=212, input_resolution=(64, 64), num_heads=4, window_size=16, shift_size=8, mlp_ratio=2
#         (norm1): LayerNorm((212,), eps=1e-05, elementwise_affine=True)
#         (attn): WindowAttention(
#           dim=212, window_size=(16, 16), num_heads=4
#           (qkv): Linear(in_features=212, out_features=636, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=212, out_features=212, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#           (softmax): Softmax(dim=-1)
#         )
#         (drop_path): DropPath()
#         (norm2): LayerNorm((212,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=212, out_features=424, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=424, out_features=212, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (adjust2): Conv2d(212, 32, kernel_size=(1, 1), stride=(1, 1))
#       (swin3): SwinTransformerBlock(
#         dim=244, input_resolution=(64, 64), num_heads=2, window_size=16, shift_size=0, mlp_ratio=2
#         (norm1): LayerNorm((244,), eps=1e-05, elementwise_affine=True)
#         (attn): WindowAttention(
#           dim=244, window_size=(16, 16), num_heads=2
#           (qkv): Linear(in_features=244, out_features=732, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=244, out_features=244, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#           (softmax): Softmax(dim=-1)
#         )
#         (drop_path): DropPath()
#         (norm2): LayerNorm((244,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=244, out_features=488, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=488, out_features=244, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (adjust3): Conv2d(244, 32, kernel_size=(1, 1), stride=(1, 1))
#       (swin4): SwinTransformerBlock(
#         dim=276, input_resolution=(64, 64), num_heads=6, window_size=16, shift_size=8, mlp_ratio=1
#         (norm1): LayerNorm((276,), eps=1e-05, elementwise_affine=True)
#         (attn): WindowAttention(
#           dim=276, window_size=(16, 16), num_heads=6
#           (qkv): Linear(in_features=276, out_features=828, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=276, out_features=276, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#           (softmax): Softmax(dim=-1)
#         )
#         (drop_path): DropPath()
#         (norm2): LayerNorm((276,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=276, out_features=276, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=276, out_features=276, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (adjust4): Conv2d(276, 32, kernel_size=(1, 1), stride=(1, 1))
#       (swin5): SwinTransformerBlock(
#         dim=308, input_resolution=(64, 64), num_heads=4, window_size=16, shift_size=0, mlp_ratio=1
#         (norm1): LayerNorm((308,), eps=1e-05, elementwise_affine=True)
#         (attn): WindowAttention(
#           dim=308, window_size=(16, 16), num_heads=4
#           (qkv): Linear(in_features=308, out_features=924, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=308, out_features=308, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#           (softmax): Softmax(dim=-1)
#         )
#         (drop_path): DropPath()
#         (norm2): LayerNorm((308,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=308, out_features=308, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=308, out_features=308, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (adjust5): Conv2d(308, 180, kernel_size=(1, 1), stride=(1, 1))
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (pe): PatchEmbed()
#       (pue): PatchUnEmbed()
#     )
#   )
#   (norm): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#   (conv_after_body): Conv2d(180, 180, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_before_upsample): Sequential(
#     (0): Conv2d(180, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (upsample): Upsample(
#     (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): PixelShuffle(upscale_factor=2)
#     (2): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): PixelShuffle(upscale_factor=2)
#   )
#   (conv_last): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )
# Testing 0 10_resized
# Testing 1 1_resized
# Testing 2 2_resized
# Testing 3 3_resized
# Testing 4 4_resized
# Testing 5 5_resized
# Testing 6 6_resized
# Testing 7 7_resized
# Testing 8 8_resized
# Testing 9 9_resized
# Cropping complete! Final images are saved in: very_big_img

# %%
# %%capture
# !pip install -q transformers==4.36.2
# !pip install git+https://github.com/openai/clip
# !pip install ftfy
# !pip install regex
# !pip install tqdm
# !pip install pillow
# !pip install pytorch
# !pip install torchvision
# !pip install opencv-contrib-python
# !pip install einops
# !pip install grad-cam
# !pip install open-clip-torch
from transformers import AutoTokenizer, BitsAndBytesConfig
import torch

# %% [markdown]
# ## Set up for GradCAM model

# %%
os.mkdir('testgradcam')
os.chdir('testgradcam')
os.mkdir('test')
os.mkdir('train')
os.chdir('test')
os.mkdir('FAKE')
os.mkdir('REAL')
os.chdir('..')
os.chdir('train')
os.mkdir('FAKE')
os.mkdir('REAL')
os.chdir('..')
os.chdir('..')

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from torchvision.models import resnet50
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
import numpy as np
import cv2
from tqdm import tqdm
import os

def load_model(model_path, device='cuda'):
    model = resnet50(pretrained=False)
    model.fc = nn.Linear(model.fc.in_features, 2)
    model.load_state_dict(torch.load(model_path))
    model.to(device)
    model.eval()
    return model
def generate_intensity_matrix(grayscale_cam, size=(32, 32)):
    # Resize the grayscale CAM to desired dimensions
    intensity_matrix = cv2.resize(grayscale_cam, size, interpolation=cv2.INTER_LINEAR)
    # Values are already normalized between 0 and 1 from GradCAM
    return intensity_matrix

def generate_gradcam_visualizations(
    model_path,
    dataset_path,
    output_dir,
    num_samples=1,  # Changed to 1 for testing
    device='cuda'
):
    # Create output directory
    os.makedirs(output_dir, exist_ok=True)

    # Load model
    model = load_model(model_path, device)

    # Define target layer for GradCAM
    target_layers = [model.layer4[-1]]
    # Initialize GradCAM
    cam = GradCAM(
        model=model,
        target_layers=target_layers,
    )

    # Setup data loading
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                           std=[0.229, 0.224, 0.225])
    ])

    # Load dataset
    dataset = torchvision.datasets.ImageFolder(
        root=dataset_path,
        transform=transform
    )

    # Select random samples
    num_samples = min(num_samples, len(dataset))
    indices = torch.randperm(len(dataset))[:num_samples]

    # Process each image
    for idx in tqdm(indices, desc="Generating Grad-CAM visualizations"):
        # Get image and label
        img_tensor, label = dataset[idx]
        input_tensor = img_tensor.unsqueeze(0)

        # Get original image for overlay
        img_path = dataset.imgs[idx][0]
        rgb_img = cv2.imread(img_path, 1)[:, :, ::-1]
        rgb_img = cv2.resize(rgb_img, (224, 224))
        rgb_img = np.float32(rgb_img) / 255

        # Generate class activation map
        grayscale_cam = cam(input_tensor=input_tensor, targets=None)
        grayscale_cam = grayscale_cam[0, :]

        # Generate 32x32 intensity matrix
        intensity_matrix = generate_intensity_matrix(grayscale_cam)

        # Save intensity matrix
        matrix_output_path = os.path.join(
            output_dir,
            f"intensity_matrix_{0}.npy"
        )
        np.save(matrix_output_path, intensity_matrix)

        # Print shape and some statistics of the intensity matrix
        print(f"Intensity Matrix Shape: {intensity_matrix.shape}")
        print(f"Min value: {intensity_matrix.min():.4f}")
        print(f"Max value: {intensity_matrix.max():.4f}")
        print(f"Mean value: {intensity_matrix.mean():.4f}")

        # Overlay CAM on original image
        visualization = show_cam_on_image(rgb_img, grayscale_cam, use_rgb=True)

        # Get model prediction
        with torch.no_grad():
            output = model(input_tensor.to(device))
            pred = output.argmax(dim=1).item()

        # Save the visualization
        output_path = os.path.join(
            output_dir,
            f"gradcam_pred_true.jpg"
        )
        cv2.imwrite(output_path, visualization[:, :, ::-1])

# %% [markdown]
# ## Classes for getting Artifact probability using CLIP

# %%
import json
import clip
import cv2
import matplotlib.pyplot as plt
import numpy as np
import torch
from PIL import Image
import open_clip


# CLIP Model Class - ViT-B/32
class Clip32b:
    def __init__(self):
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        self.model, self.preprocess = clip.load("ViT-B/32", device=self.device)
        total_params = sum(p.numel() for p in self.model.parameters())
        print("Total params: ", total_params)

    def image_text_search(self, image_patches, text_descriptions):
        """
        Compute text-image similarity for each patch and return scores.
        """
        text = clip.tokenize(text_descriptions).to(self.device)
        patch_results = []

        for patch in image_patches:
            patch = self.preprocess(patch).unsqueeze(0).to(self.device)
            with torch.no_grad():
                logits_per_image, _ = self.model(patch, text)
                probs = logits_per_image.softmax(dim=-1).cpu().numpy()
            patch_results.append(probs[0])

        return np.array(patch_results)

    def split_image_into_patches(self, image, patch_size, intensities):
        """
        Split the image into non-overlapping patches of size (patch_size x patch_size).
        """
        image = np.array(image)
        h, w, c = image.shape
        patches = []
        intensity = []

        for i in range(0, h, patch_size):
            for j in range(0, w, patch_size):
                patch = image[i: i + patch_size, j: j + patch_size]
                gradpatch = intensities[i: i + patch_size, j: j + patch_size]
                if patch.shape[:2] == (patch_size, patch_size):
                    patches.append(Image.fromarray(patch))
                    intensity.append(np.sum(gradpatch))

        return patches, intensity

    def give_result(self, patch_results, patch_weights):
        """
        Perform majority voting to determine the most frequent description.
        """
        votes = np.argmax(patch_results, axis=1)
        if np.sum((votes != 2) * patch_weights) != 0:
            weighted_avg = np.sum((votes == 0) * patch_weights) / np.sum((votes != 2) * patch_weights)
        else:
            weighted_avg = 0
        return weighted_avg

    def final_img_process(self, description_list, image_path, small=1):
        """
        Perform patch-based processing on the image and return weighted average similarity.
        """
        patch_sizes = [32, 64, 128, 256] if small == 1 else [32]
        image = Image.open(image_path)
        intensity = np.load("/gradcam_visualizations/intensity_matrix_0.npy")
        intensity = np.array(Image.fromarray(intensity).resize((128, 128)))

        all_results, all_weights = [], []
        for patch_size in patch_sizes:
            patches, patch_intensity = self.split_image_into_patches(image, patch_size, intensity)
            patch_results = self.image_text_search(patches, description_list)
            all_results.append(list(patch_results))
            all_weights.append(patch_intensity)

        stacked_results = np.array([i for j in all_results for i in j])
        stacked_weights = np.array([i for j in all_weights for i in j])
        return self.give_result(stacked_results, stacked_weights)


# CLIP Model Class - ViT-H/14
class Clip14h:
    def __init__(self):
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        self.model, _, self.preprocess = open_clip.create_model_and_transforms(
            "ViT-H-14-quickgelu", pretrained="dfn5b", device=self.device
        )
        self.tokenizer = open_clip.get_tokenizer("ViT-H-14-quickgelu")
        total_params = sum(p.numel() for p in self.model.parameters())
        print("Total params: ", total_params)

    def image_text_search(self, image_patches, text_descriptions):
        """
        Compute text-image similarity for each patch and return scores.
        """
        text = self.tokenizer(text_descriptions).to(self.device)
        patch_results = []

        for patch in image_patches:
            patch = self.preprocess(patch).unsqueeze(0).to(self.device)
            with torch.no_grad(), torch.cuda.amp.autocast():
                image_features = self.model.encode_image(patch).to(self.device)
                text_features = self.model.encode_text(text).to(self.device)
                image_features /= image_features.norm(dim=-1, keepdim=True)
                text_features /= text_features.norm(dim=-1, keepdim=True)
                probs = (image_features @ text_features.T).softmax(dim=-1).cpu().numpy()
            patch_results.append(probs[0])

        return np.array(patch_results)

    def split_image_into_patches(self, image, patch_size, intensities):
        """
        Split the image into non-overlapping patches of size (patch_size x patch_size).
        """
        image = np.array(image)
        h, w, c = image.shape
        patches = []
        intensity = []

        for i in range(0, h, patch_size):
            for j in range(0, w, patch_size):
                patch = image[i: i + patch_size, j: j + patch_size]
                gradpatch = intensities[i: i + patch_size, j: j + patch_size]
                if patch.shape[:2] == (patch_size, patch_size):
                    patches.append(Image.fromarray(patch))
                    intensity.append(np.sum(gradpatch))

        return patches, intensity

    def give_result(self, patch_results, patch_weights):
        """
        Perform majority voting to determine the most frequent description.
        """
        votes = np.argmax(patch_results, axis=1)
        if np.sum((votes != 2) * patch_weights) != 0:
            weighted_avg = np.sum((votes == 0) * patch_weights) / np.sum((votes != 2) * patch_weights)
        else:
            weighted_avg = 0
        return weighted_avg

    def final_img_process(self, description_list, image_path, small=1):
        """
        Perform patch-based processing on the image and return weighted average similarity.
        """
        patch_sizes = [32, 64, 128, 256] if small == 1 else [32]
        image = Image.open(image_path)
        intensity = np.load("gradcam_visualizations/intensity_matrix_0.npy")
        intensity = np.array(Image.fromarray(intensity).resize((128, 128)))

        all_results, all_weights = [], []
        for patch_size in patch_sizes:
            patches, patch_intensity = self.split_image_into_patches(image, patch_size, intensity)
            patch_results = self.image_text_search(patches, description_list)
            all_results.append(list(patch_results))
            all_weights.append(patch_intensity)

        stacked_results = np.array([i for j in all_results for i in j])
        stacked_weights = np.array([i for j in all_weights for i in j])
        return self.give_result(stacked_results, stacked_weights)

# %%
animal_artifacts = [
    "Dental anomalies in mammals",
    "Anatomically incorrect paw structures",
    "Unrealistic eye reflections",
    "Misshapen ears or appendages",
    "Unnatural pose artifacts",
    "Biological asymmetry errors",
    "Impossible foreshortening in animal bodies",
    "Anatomically impossible joint configurations",
    "Misaligned bilateral elements in animal faces",
    "Improper fur direction flows",
    "Incorrect skin tones",
    "Asymmetric features in naturally symmetric objects"
]
vehicle_artifacts = [
    "Impossible mechanical connections",
    "Impossible mechanical joints",
    "Physically impossible structural elements",
    "Incorrect wheel geometry",
    "Implausible aerodynamic structures",
    "Misaligned body panels",
    "Distorted window reflections",
    "Incorrect reflection mapping",
    "Non-manifold geometries in rigid structures",
    "Irregular proportions in mechanical components",
    "Inconsistent scale of mechanical parts",
    "Metallic surface artifacts",
    "Floating or disconnected components",
    "Unnaturally glossy surfaces"
]

# %%
import os
import pandas as pd
import torch
from PIL import Image
import json

def find_artifacts_in_image(folder_path, threshold_sr=0.5, threshold_non_sr=0.8):
    sr_artifacts = [
        "Incorrect reflection mapping", "Abruptly cut off objects", "Ghosting effects: Semi-transparent duplicates of elements",
        "Dental anomalies in mammals", "Anatomically incorrect paw structures", "Unrealistic eye reflections",
        "Misshapen ears or appendages", "Unnatural pose artifacts", "Biological asymmetry errors",
        "Impossible foreshortening in animal bodies", "Impossible mechanical connections", "Impossible mechanical joints",
        "Physically impossible structural elements", "Incorrect wheel geometry", "Implausible aerodynamic structures",
        "Misaligned body panels", "Distorted window reflections", "Anatomically impossible joint configurations",
        "Non-manifold geometries in rigid structures", "Asymmetric features in naturally symmetric objects",
        "Misaligned bilateral elements in animal faces", "Irregular proportions in mechanical components",
        "Inconsistent scale of mechanical parts", "Incorrect perspective rendering", "Scale inconsistencies within single objects",
        "Spatial relationship errors", "Scale inconsistencies within the same object class", "Depth perception anomalies"
    ]
    non_sr_artifacts = [
        "Improper fur direction flows", "Incorrect skin tones", "Inconsistent object boundaries",
        "Blurred boundaries in fine details", "Over-sharpening artifacts", "Excessive sharpness in certain image regions",
        "Aliasing along high-contrast edges", "Jagged edges in curved structures", "Fake depth of field",
        "Artificial depth of field in object presentation", "Discontinuous surfaces", "Unnaturally glossy surfaces",
        "Metallic surface artifacts", "Texture bleeding between adjacent regions", "Texture repetition patterns",
        "Over-smoothing of natural textures", "Regular grid-like artifacts in textures", "Artificial noise patterns in uniform surfaces",
        "Random noise patterns in detailed areas", "Repeated element patterns", "Systematic color distribution anomalies",
        "Unnatural color transitions", "Color coherence breaks", "Frequency domain signatures",
        "Artificial smoothness", "Cinematization effects", "Movie-poster-like composition of ordinary scenes",
        "Exaggerated characteristic features", "Synthetic material appearance", "Floating or disconnected components",
        "Inconsistent material properties", "Depth perception anomalies", "Loss of fine detail in complex structures",
        "Resolution inconsistencies within regions", "Abruptly cut off objects", "Unrealistic specular highlights"
    ]

    # Load artifact descriptions
    tuple_desc = pd.read_csv('Artifact_descriptions/Artifact_description_Tuple.csv')

    result = {}
    animal_or_vehicle = Clip32b()
    artifact_detector = Clip14h()
    print("Loaded artifact detector")

    for filename in os.listdir(folder_path):
        if filename.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".gif")):
            # Process image
            image_path = os.path.join(folder_path, filename)
            image = Image.open(image_path)
            image.save("testgradcam/test/FAKE/peg32.png")
            image.save("testgradcam/test/REAL/peg32.png")
            image.save("testgradcam/train/FAKE/peg32.png")
            image.save("testgradcam/train/REAL/peg32.png")

            # Generate Grad-CAM visualizations
            generate_gradcam_visualizations(
                model_path='Model_weights/fake_detector.pth',
                dataset_path='testgradcam',
                output_dir='gradcam_visualizations',
                num_samples=1,
                device='cuda' if torch.cuda.is_available() else 'cpu'
            )

            # Determine if the image is an animal or a vehicle
            probab_animal_vehicle = animal_or_vehicle.image_text_search(
                [Image.open(f"very_big_img/{filename[:-4]}_resized_DRCT-L_X4.png")],
                ["Vehicle", "Animal"]
            )[0]
            predicted_class = int(probab_animal_vehicle[0] < probab_animal_vehicle[1])
            if predicted_class:
                print("ANIMAL DETECTED!!!!!!")

            artifacts_present = []

            # Process SR artifacts
            for artifact in sr_artifacts:
                row = tuple_desc[tuple_desc['Artifact'] == artifact]
                if not row.empty:
                    description = row.iloc[0, 1:].tolist()
                else:
                    continue

                if predicted_class == 0 and artifact in animal_artifacts:
                    continue
                if predicted_class == 1 and artifact in vehicle_artifacts:
                    continue

                print(description)
                score = artifact_detector.final_img_process(
                    description, f"very_big_img/{filename[:-4]}_resized_DRCT-L_X4.png"
                )

                if score > threshold_sr:
                    artifacts_present.append(artifact)
                print(filename, "processed for", artifact, "with probability of", score)

            # Process Non-SR artifacts
            for artifact in non_sr_artifacts:
                row = tuple_desc[tuple_desc['Artifact'] == artifact]
                if not row.empty:
                    description = row.iloc[0, 1:].tolist()
                else:
                    continue

                print(description)
                score = artifact_detector.final_img_process(
                    description,  f"very_big_img/{filename[:-4]}_resized_DRCT-L_X4.png"
                )

                if score > threshold_non_sr:
                    artifacts_present.append(artifact)
                print(filename, "processed for", artifact, "with probability of", score)

            result[filename] = artifacts_present

    return result

# %% [markdown]
# ## Detect Artifacts

# %%
results = find_artifacts_in_image(input_folder, 0.85, 0.9)
with open("Artifacts_detected.json", "w") as file:
    json.dump(results, file, indent=4)
# Out:
# Total params:  151277313
# Total params:  986109441
# Loaded artifact detector
# /root/miniconda3/envs/py3.10/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /root/miniconda3/envs/py3.10/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /tmp/ipykernel_103/4231269379.py:18: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# Generating Grad-CAM visualizations: 100%|██████████| 1/1 [00:00<00:00, 29.60it/s]
# /tmp/ipykernel_103/1268349006.py:106: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), torch.cuda.amp.autocast():
# Intensity Matrix Shape: (32, 32)
# Min value: 0.0000
# Max value: 0.9577
# Mean value: 0.3006
# ANIMAL DETECTED!!!!!!
# ['Cut off object', 'Full object', 'No object']
# 1.png processed for Abruptly cut off objects with probability of 0.2811575
# ['Unnatural teeth', 'Natural teeth', 'No teeth']
# 1.png processed for Dental anomalies in mammals with probability of 1.0
# ['Unnatural paw shape', 'Natural paw shape', 'No paws']
# 1.png processed for Anatomically incorrect paw structures with probability of 1.0
# ['Unnatural ear shape', 'Natural ear shape', 'No ears']
# 1.png processed for Misshapen ears or appendages with probability of 0.9263857
# ['Unnatural pose', 'Natural pose', 'Vehicle']
# 1.png processed for Unnatural pose artifacts with probability of 1.0
# ['Asymmetric body', 'Symmetric body', 'Vehicle']
# 1.png processed for Biological asymmetry errors with probability of 0.545261
# ['Irregular limb size', 'Natural limb size', 'Vehicle']
# 1.png processed for Impossible foreshortening in animal bodies with probability of 0.33333334
# ['Incorrect limb joints', 'Correct limb joints', 'No limb joints']
# 1.png processed for Anatomically impossible joint configurations with probability of 0
# ['Asymmetric objects', 'Symmetric objects', 'No object']
# 1.png processed for Asymmetric features in naturally symmetric objects with probability of 1.0
# ['Asymmetric face', 'Symmetric face', 'No animal ']
# 1.png processed for Misaligned bilateral elements in animal faces with probability of 0.9998747
# ['Unnatural perspective view', 'Natural perspective view', 'No perspective view']
# 1.png processed for Incorrect perspective rendering with probability of 1.0
# ['Incorrectly positioned Objects', 'Correctly positioned Objects', 'No object']
# 1.png processed for Spatial relationship errors with probability of 1.0
# ['Different size objects', 'Same size objects', 'Single object']
# 1.png processed for Scale inconsistencies within the same object class with probability of 0.0
# ['Unnatural depth', 'Natural depth', 'No depth']
# 1.png processed for Depth perception anomalies with probability of 0.98749864
# ['Unnatural fur flow', 'Natural fur flow', 'No fur']
# 1.png processed for Improper fur direction flows with probability of 1.0
# ['Unnatural skin colours', 'Natural skin colours', 'No skin']
# 1.png processed for Incorrect skin tones with probability of 1.0
# ['Discontinuous Boundaries', 'Continuous Boundaries', 'No Boundaries']
# 1.png processed for Inconsistent object boundaries with probability of 0.88425726
# ['Unnatural sharp edges', 'Natural sharp edges', 'Soft edges']
# 1.png processed for Over-sharpening artifacts with probability of 0.3506777
# ['Over-sharp areas', 'No sharp areas', 'IRRELEVANT']
# 1.png processed for Excessive sharpness in certain image regions with probability of 1.0
# ['Jagged light boundary', 'Smooth light boundary', 'No light boundary']
# 1.png processed for Aliasing along high-contrast edges with probability of 0.16338567
# ['Pixelated, uneven curves', 'Smooth, clean curves', 'Geometric Objects']
# 1.png processed for Jagged edges in curved structures with probability of 1.0
# ['Unnatural depth', 'Natural depth', 'No depth']
# 1.png processed for Fake depth of field with probability of 0.98749864
# ['Unnatural depth', 'Natural depth', 'No depth']
# 1.png processed for Artificial depth of field in object presentation with probability of 0.98749864
# ['Broken and Discontinuous Surfaces', 'Smooth, Realistic Continuous Surfaces', 'No Surfaces']
# 1.png processed for Discontinuous surfaces with probability of 0.10683057
# ['Unnatural Glossy surface', 'Realistic glossy surface', 'Matte surface']
# 1.png processed for Unnaturally glossy surfaces with probability of 1.0
# ['Unnatural Metallic Reflections', 'Realistic Metallic reflections', 'Metallic Surface']
# 1.png processed for Metallic surface artifacts with probability of 0.846199
# ['Discontinuous textures', 'Continuous textures', 'IRRELEVANT']
# 1.png processed for Texture bleeding between adjacent regions with probability of 0.9587675
# ['Unnatural Texture repetition patterns', 'Natural Texture Variation', 'Organic Objects']
# 1.png processed for Texture repetition patterns with probability of 0.4181965
# ['Unnatural smooth texture', 'Realistic smooth texture', 'Rough texture']
# 1.png processed for Over-smoothing of natural textures with probability of 0.64627016
# ['Grid patterns', 'No grid patterns', 'No surfaces']
# 1.png processed for Regular grid-like artifacts in textures with probability of 0.0
# ['Unnatural noise in uniform surfaces', 'Natural noise in uniform surfaces', 'No surfaces']
# 1.png processed for Artificial noise patterns in uniform surfaces with probability of 0.6666666
# ['Repeated pattern', 'Unique pattern', 'No pattern']
# 1.png processed for Repeated element patterns with probability of 1.0
# ['Uneven or jarring color patterns', 'Even and natural color distribution', 'Black and white']
# 1.png processed for Systematic color distribution anomalies with probability of 0.6665983
# ['Discontinous colour transition', 'Natural colour transition', 'Black and white']
# 1.png processed for Unnatural color transitions with probability of 0.9653202
# ['Unnatural colour transition', 'Natural colour transition', 'Black and white']
# 1.png processed for Color coherence breaks with probability of 0.9887385
# ['Unnatural patterns in frequencies', 'Natural frequency patterns', 'IRRELEVANT']
# 1.png processed for Frequency domain signatures with probability of 0.9396622
# ['Unnatural smoothness ', 'Natural smoothness', 'Roughness']
# 1.png processed for Artificial smoothness with probability of 1.0
# ['Highly detailed', 'Natural detailed', 'Blur']
# 1.png processed for Exaggerated characteristic features with probability of 0.0
# ['Unnatural Plastic surface', 'Natural plastic surface', 'No plastic']
# 1.png processed for Synthetic material appearance with probability of 1.0
# ['Disconnected components', 'Connected components', 'No components']
# 1.png processed for Floating or disconnected components with probability of 0.77164483
# ['Unnatural materials', 'Realistic materials', 'No material']
# 1.png processed for Inconsistent material properties with probability of 0.53353566
# ['Unnatural depth', 'Natural depth', 'No depth']
# 1.png processed for Depth perception anomalies with probability of 0.98749864
# ['Blurry and sharp areas', 'Consistent sharpness across the image', 'Uniform Resolution']
# 1.png processed for Resolution inconsistencies within regions with probability of 0.35477242
# ['Cut off object', 'Full object', 'No object']
# 1.png processed for Abruptly cut off objects with probability of 0.2811575
# Generating Grad-CAM visualizations: 100%|██████████| 1/1 [00:00<00:00, 36.07it/s]
# Intensity Matrix Shape: (32, 32)
# Min value: 0.0000
# Max value: 0.9801
# Mean value: 0.2110
# ANIMAL DETECTED!!!!!!
# ['Cut off object', 'Full object', 'No object']
# 9.png processed for Abruptly cut off objects with probability of 0.17873985
# ['Unnatural teeth', 'Natural teeth', 'No teeth']
# 9.png processed for Dental anomalies in mammals with probability of 0.8329476
# ['Unnatural paw shape', 'Natural paw shape', 'No paws']
# 9.png processed for Anatomically incorrect paw structures with probability of 0.7968692
# ['Unnatural ear shape', 'Natural ear shape', 'No ears']
# 9.png processed for Misshapen ears or appendages with probability of 0.4145343
# ['Unnatural pose', 'Natural pose', 'Vehicle']
# 9.png processed for Unnatural pose artifacts with probability of 1.0
# ['Asymmetric body', 'Symmetric body', 'Vehicle']
# 9.png processed for Biological asymmetry errors with probability of 0.5730935
# ['Irregular limb size', 'Natural limb size', 'Vehicle']
# 9.png processed for Impossible foreshortening in animal bodies with probability of 0.5116542
# ['Incorrect limb joints', 'Correct limb joints', 'No limb joints']
# 9.png processed for Anatomically impossible joint configurations with probability of 0
# ['Asymmetric objects', 'Symmetric objects', 'No object']
# 9.png processed for Asymmetric features in naturally symmetric objects with probability of 0.9604787
# ['Asymmetric face', 'Symmetric face', 'No animal ']
# 9.png processed for Misaligned bilateral elements in animal faces with probability of 1.0
# ['Unnatural perspective view', 'Natural perspective view', 'No perspective view']
# 9.png processed for Incorrect perspective rendering with probability of 1.0
# ['Incorrectly positioned Objects', 'Correctly positioned Objects', 'No object']
# 9.png processed for Spatial relationship errors with probability of 0.6664409
# ['Different size objects', 'Same size objects', 'Single object']
# 9.png processed for Scale inconsistencies within the same object class with probability of 0.0
# ['Unnatural depth', 'Natural depth', 'No depth']
# 9.png processed for Depth perception anomalies with probability of 0.9190756
# ['Unnatural fur flow', 'Natural fur flow', 'No fur']
# 9.png processed for Improper fur direction flows with probability of 1.0
# ['Unnatural skin colours', 'Natural skin colours', 'No skin']
# 9.png processed for Incorrect skin tones with probability of 1.0
# ['Discontinuous Boundaries', 'Continuous Boundaries', 'No Boundaries']
# 9.png processed for Inconsistent object boundaries with probability of 0.8971747
# ['Unnatural sharp edges', 'Natural sharp edges', 'Soft edges']
# 9.png processed for Over-sharpening artifacts with probability of 0.348303
# ['Over-sharp areas', 'No sharp areas', 'IRRELEVANT']
# 9.png processed for Excessive sharpness in certain image regions with probability of 1.0
# ['Jagged light boundary', 'Smooth light boundary', 'No light boundary']
# 9.png processed for Aliasing along high-contrast edges with probability of 0.20312007
# ['Pixelated, uneven curves', 'Smooth, clean curves', 'Geometric Objects']
# 9.png processed for Jagged edges in curved structures with probability of 0.6666666
# ['Unnatural depth', 'Natural depth', 'No depth']
# 9.png processed for Fake depth of field with probability of 0.9190756
# ['Unnatural depth', 'Natural depth', 'No depth']
# 9.png processed for Artificial depth of field in object presentation with probability of 0.9190756
# ['Broken and Discontinuous Surfaces', 'Smooth, Realistic Continuous Surfaces', 'No Surfaces']
# 9.png processed for Discontinuous surfaces with probability of 0.4853065
# ['Unnatural Glossy surface', 'Realistic glossy surface', 'Matte surface']
# 9.png processed for Unnaturally glossy surfaces with probability of 1.0
# ['Unnatural Metallic Reflections', 'Realistic Metallic reflections', 'Metallic Surface']
# 9.png processed for Metallic surface artifacts with probability of 0.7087166
# ['Discontinuous textures', 'Continuous textures', 'IRRELEVANT']
# 9.png processed for Texture bleeding between adjacent regions with probability of 0.76565576
# ['Unnatural Texture repetition patterns', 'Natural Texture Variation', 'Organic Objects']
# 9.png processed for Texture repetition patterns with probability of 0.4694589
# ['Unnatural smooth texture', 'Realistic smooth texture', 'Rough texture']
# 9.png processed for Over-smoothing of natural textures with probability of 1.0
# ['Grid patterns', 'No grid patterns', 'No surfaces']
# 9.png processed for Regular grid-like artifacts in textures with probability of 0.0
# ['Unnatural noise in uniform surfaces', 'Natural noise in uniform surfaces', 'No surfaces']
# 9.png processed for Artificial noise patterns in uniform surfaces with probability of 1.0
# ['Repeated pattern', 'Unique pattern', 'No pattern']
# 9.png processed for Repeated element patterns with probability of 0.81737727
# ['Uneven or jarring color patterns', 'Even and natural color distribution', 'Black and white']
# 9.png processed for Systematic color distribution anomalies with probability of 1.0
# ['Discontinous colour transition', 'Natural colour transition', 'Black and white']
# 9.png processed for Unnatural color transitions with probability of 0.77176315
# ['Unnatural colour transition', 'Natural colour transition', 'Black and white']
# 9.png processed for Color coherence breaks with probability of 0.9067128
# ['Unnatural patterns in frequencies', 'Natural frequency patterns', 'IRRELEVANT']
# 9.png processed for Frequency domain signatures with probability of 0.7046912
# ['Unnatural smoothness ', 'Natural smoothness', 'Roughness']
# 9.png processed for Artificial smoothness with probability of 1.0
# ['Highly detailed', 'Natural detailed', 'Blur']
# 9.png processed for Exaggerated characteristic features with probability of 0.0
# ['Unnatural Plastic surface', 'Natural plastic surface', 'No plastic']
# 9.png processed for Synthetic material appearance with probability of 1.0
# ['Disconnected components', 'Connected components', 'No components']
# 9.png processed for Floating or disconnected components with probability of 0.6699716
# ['Unnatural materials', 'Realistic materials', 'No material']
# 9.png processed for Inconsistent material properties with probability of 0.47670805
# ['Unnatural depth', 'Natural depth', 'No depth']
# 9.png processed for Depth perception anomalies with probability of 0.9190756
# ['Blurry and sharp areas', 'Consistent sharpness across the image', 'Uniform Resolution']
# 9.png processed for Resolution inconsistencies within regions with probability of 0.4883458
# ['Cut off object', 'Full object', 'No object']
# 9.png processed for Abruptly cut off objects with probability of 0.17873985
# Generating Grad-CAM visualizations: 100%|██████████| 1/1 [00:00<00:00, 39.42it/s]
# Intensity Matrix Shape: (32, 32)
# Min value: 0.0000
# Max value: 0.9984
# Mean value: 0.2073
# ['Unnatural reflections', 'Natural reflections', 'No reflections']
# 7.png processed for Incorrect reflection mapping with probability of 1.0
# ['Cut off object', 'Full object', 'No object']
# 7.png processed for Abruptly cut off objects with probability of 0.7331748
# ['Incorrect mechanical connection', 'Correct mechanical connection', 'No mechanical connection']
# 7.png processed for Impossible mechanical connections with probability of 0.84108686
# ['Unnatural mechanical joints', 'Natural mechanical joints', 'No mechanical joints']
# 7.png processed for Impossible mechanical joints with probability of 0
# ['Unreal wheels', 'Round wheels', 'No wheels']
# 7.png processed for Incorrect wheel geometry with probability of 0.09292712
# ['Unreal aeroplane', 'Real aeroplane', 'No aeroplane']
# 7.png processed for Implausible aerodynamic structures with probability of 0.5423167
# ['Panels not aligned properly', 'Panels aligned smoothly', 'Animal']
# 7.png processed for Misaligned body panels with probability of 0.43129143
# ['Incorrect window reflection', 'Correct window reflection', 'No window']
# 7.png processed for Distorted window reflections with probability of 0.9910531
# ['Unnatural Shapes', 'Natural Shapes', 'No Rigid Structures']
# 7.png processed for Non-manifold geometries in rigid structures with probability of 1.0
# ['Irregular sized parts', 'Regular sized parts', 'No Mechanical Parts']
# 7.png processed for Irregular proportions in mechanical components with probability of 0.877542
# ['Irregular sized parts', 'Regular sized parts', 'No Mechanical Parts']
# 7.png processed for Inconsistent scale of mechanical parts with probability of 0.877542
# ['Unnatural perspective view', 'Natural perspective view', 'No perspective view']
# 7.png processed for Incorrect perspective rendering with probability of 0
# ['Incorrectly positioned Objects', 'Correctly positioned Objects', 'No object']
# 7.png processed for Spatial relationship errors with probability of 1.0
# ['Different size objects', 'Same size objects', 'Single object']
# 7.png processed for Scale inconsistencies within the same object class with probability of 0.0
# ['Unnatural depth', 'Natural depth', 'No depth']
# 7.png processed for Depth perception anomalies with probability of 1.0
# ['Unnatural fur flow', 'Natural fur flow', 'No fur']
# 7.png processed for Improper fur direction flows with probability of 1.0
# ['Unnatural skin colours', 'Natural skin colours', 'No skin']
# 7.png processed for Incorrect skin tones with probability of 0.9508701
# ['Discontinuous Boundaries', 'Continuous Boundaries', 'No Boundaries']
# 7.png processed for Inconsistent object boundaries with probability of 0.43157384
# ['Unnatural sharp edges', 'Natural sharp edges', 'Soft edges']
# 7.png processed for Over-sharpening artifacts with probability of 0.81927943
# ['Over-sharp areas', 'No sharp areas', 'IRRELEVANT']
# 7.png processed for Excessive sharpness in certain image regions with probability of 1.0
# ['Jagged light boundary', 'Smooth light boundary', 'No light boundary']
# 7.png processed for Aliasing along high-contrast edges with probability of 0.43547586
# ['Pixelated, uneven curves', 'Smooth, clean curves', 'Geometric Objects']
# 7.png processed for Jagged edges in curved structures with probability of 1.0
# ['Unnatural depth', 'Natural depth', 'No depth']
# 7.png processed for Fake depth of field with probability of 1.0
# ['Unnatural depth', 'Natural depth', 'No depth']
# 7.png processed for Artificial depth of field in object presentation with probability of 1.0
# ['Broken and Discontinuous Surfaces', 'Smooth, Realistic Continuous Surfaces', 'No Surfaces']
# 7.png processed for Discontinuous surfaces with probability of 0.49933907
# ['Unnatural Glossy surface', 'Realistic glossy surface', 'Matte surface']
# 7.png processed for Unnaturally glossy surfaces with probability of 1.0
# ['Unnatural Metallic Reflections', 'Realistic Metallic reflections', 'Metallic Surface']
# 7.png processed for Metallic surface artifacts with probability of 0.48151988
# ['Discontinuous textures', 'Continuous textures', 'IRRELEVANT']
# 7.png processed for Texture bleeding between adjacent regions with probability of 0.7230596
# ['Unnatural Texture repetition patterns', 'Natural Texture Variation', 'Organic Objects']
# 7.png processed for Texture repetition patterns with probability of 0.54886436
# ['Unnatural smooth texture', 'Realistic smooth texture', 'Rough texture']
# 7.png processed for Over-smoothing of natural textures with probability of 1.0
# ['Grid patterns', 'No grid patterns', 'No surfaces']
# 7.png processed for Regular grid-like artifacts in textures with probability of 0.0
# ['Unnatural noise in uniform surfaces', 'Natural noise in uniform surfaces', 'No surfaces']
# 7.png processed for Artificial noise patterns in uniform surfaces with probability of 1.0
# ['Repeated pattern', 'Unique pattern', 'No pattern']
# 7.png processed for Repeated element patterns with probability of 1.0
# ['Uneven or jarring color patterns', 'Even and natural color distribution', 'Black and white']
# 7.png processed for Systematic color distribution anomalies with probability of 0.88117915
# ['Discontinous colour transition', 'Natural colour transition', 'Black and white']
# 7.png processed for Unnatural color transitions with probability of 0.8133622
# ['Unnatural colour transition', 'Natural colour transition', 'Black and white']
# 7.png processed for Color coherence breaks with probability of 0.63108057
# ['Unnatural patterns in frequencies', 'Natural frequency patterns', 'IRRELEVANT']
# 7.png processed for Frequency domain signatures with probability of 0.93179286
# ['Unnatural smoothness ', 'Natural smoothness', 'Roughness']
# 7.png processed for Artificial smoothness with probability of 1.0
# ['Highly detailed', 'Natural detailed', 'Blur']
# 7.png processed for Exaggerated characteristic features with probability of 0.0
# ['Unnatural Plastic surface', 'Natural plastic surface', 'No plastic']
# 7.png processed for Synthetic material appearance with probability of 1.0
# ['Disconnected components', 'Connected components', 'No components']
# 7.png processed for Floating or disconnected components with probability of 0.8385002
# ['Unnatural materials', 'Realistic materials', 'No material']
# 7.png processed for Inconsistent material properties with probability of 0.049938377
# ['Unnatural depth', 'Natural depth', 'No depth']
# 7.png processed for Depth perception anomalies with probability of 1.0
# ['Blurry and sharp areas', 'Consistent sharpness across the image', 'Uniform Resolution']
# 7.png processed for Resolution inconsistencies within regions with probability of 0.41493118
# ['Cut off object', 'Full object', 'No object']
# 7.png processed for Abruptly cut off objects with probability of 0.7331748
# Generating Grad-CAM visualizations: 100%|██████████| 1/1 [00:00<00:00, 39.35it/s]
# Intensity Matrix Shape: (32, 32)
# Min value: 0.0000
# Max value: 0.9342
# Mean value: 0.1476
# ANIMAL DETECTED!!!!!!
# ['Cut off object', 'Full object', 'No object']
# 3.png processed for Abruptly cut off objects with probability of 0.10627517
# ['Unnatural teeth', 'Natural teeth', 'No teeth']
# 3.png processed for Dental anomalies in mammals with probability of 1.0
# ['Unnatural paw shape', 'Natural paw shape', 'No paws']
# 3.png processed for Anatomically incorrect paw structures with probability of 0.99707276
# ['Unnatural ear shape', 'Natural ear shape', 'No ears']
# 3.png processed for Misshapen ears or appendages with probability of 0.8553055
# ['Unnatural pose', 'Natural pose', 'Vehicle']
# 3.png processed for Unnatural pose artifacts with probability of 1.0
# ['Asymmetric body', 'Symmetric body', 'Vehicle']
# 3.png processed for Biological asymmetry errors with probability of 0.3233572
# ['Irregular limb size', 'Natural limb size', 'Vehicle']
# 3.png processed for Impossible foreshortening in animal bodies with probability of 0.51646143
# ['Incorrect limb joints', 'Correct limb joints', 'No limb joints']
# 3.png processed for Anatomically impossible joint configurations with probability of 0
# ['Asymmetric objects', 'Symmetric objects', 'No object']
# 3.png processed for Asymmetric features in naturally symmetric objects with probability of 1.0
# ['Asymmetric face', 'Symmetric face', 'No animal ']
# 3.png processed for Misaligned bilateral elements in animal faces with probability of 1.0
# ['Unnatural perspective view', 'Natural perspective view', 'No perspective view']
# 3.png processed for Incorrect perspective rendering with probability of 1.0
# ['Incorrectly positioned Objects', 'Correctly positioned Objects', 'No object']
# 3.png processed for Spatial relationship errors with probability of 1.0
# ['Different size objects', 'Same size objects', 'Single object']
# 3.png processed for Scale inconsistencies within the same object class with probability of 0.0
# ['Unnatural depth', 'Natural depth', 'No depth']
# 3.png processed for Depth perception anomalies with probability of 0.99852866
# ['Unnatural fur flow', 'Natural fur flow', 'No fur']
# 3.png processed for Improper fur direction flows with probability of 1.0
# ['Unnatural skin colours', 'Natural skin colours', 'No skin']
# 3.png processed for Incorrect skin tones with probability of 1.0
# ['Discontinuous Boundaries', 'Continuous Boundaries', 'No Boundaries']
# 3.png processed for Inconsistent object boundaries with probability of 0.8864509
# ['Unnatural sharp edges', 'Natural sharp edges', 'Soft edges']
# 3.png processed for Over-sharpening artifacts with probability of 0.0
# ['Over-sharp areas', 'No sharp areas', 'IRRELEVANT']
# 3.png processed for Excessive sharpness in certain image regions with probability of 1.0
# ['Jagged light boundary', 'Smooth light boundary', 'No light boundary']
# 3.png processed for Aliasing along high-contrast edges with probability of 0.1707308
# ['Pixelated, uneven curves', 'Smooth, clean curves', 'Geometric Objects']
# 3.png processed for Jagged edges in curved structures with probability of 1.0
# ['Unnatural depth', 'Natural depth', 'No depth']
# 3.png processed for Fake depth of field with probability of 0.99852866
# ['Unnatural depth', 'Natural depth', 'No depth']
# 3.png processed for Artificial depth of field in object presentation with probability of 0.99852866
# ['Broken and Discontinuous Surfaces', 'Smooth, Realistic Continuous Surfaces', 'No Surfaces']
# 3.png processed for Discontinuous surfaces with probability of 0.5616166
# ['Unnatural Glossy surface', 'Realistic glossy surface', 'Matte surface']
# 3.png processed for Unnaturally glossy surfaces with probability of 1.0
# ['Unnatural Metallic Reflections', 'Realistic Metallic reflections', 'Metallic Surface']
# 3.png processed for Metallic surface artifacts with probability of 0.9867207
# ['Discontinuous textures', 'Continuous textures', 'IRRELEVANT']
# 3.png processed for Texture bleeding between adjacent regions with probability of 0.95779085
# ['Unnatural Texture repetition patterns', 'Natural Texture Variation', 'Organic Objects']
# 3.png processed for Texture repetition patterns with probability of 0.3030516
# ['Unnatural smooth texture', 'Realistic smooth texture', 'Rough texture']
# 3.png processed for Over-smoothing of natural textures with probability of 0.55193394
# ['Grid patterns', 'No grid patterns', 'No surfaces']
# 3.png processed for Regular grid-like artifacts in textures with probability of 0.0
# ['Unnatural noise in uniform surfaces', 'Natural noise in uniform surfaces', 'No surfaces']
# 3.png processed for Artificial noise patterns in uniform surfaces with probability of 1.0
# ['Repeated pattern', 'Unique pattern', 'No pattern']
# 3.png processed for Repeated element patterns with probability of 1.0
# ['Uneven or jarring color patterns', 'Even and natural color distribution', 'Black and white']
# 3.png processed for Systematic color distribution anomalies with probability of 1.0
# ['Discontinous colour transition', 'Natural colour transition', 'Black and white']
# 3.png processed for Unnatural color transitions with probability of 0.96976185
# ['Unnatural colour transition', 'Natural colour transition', 'Black and white']
# 3.png processed for Color coherence breaks with probability of 1.0
# ['Unnatural patterns in frequencies', 'Natural frequency patterns', 'IRRELEVANT']
# 3.png processed for Frequency domain signatures with probability of 0.9979605
# ['Unnatural smoothness ', 'Natural smoothness', 'Roughness']
# 3.png processed for Artificial smoothness with probability of 1.0
# ['Highly detailed', 'Natural detailed', 'Blur']
# 3.png processed for Exaggerated characteristic features with probability of 0.0
# ['Unnatural Plastic surface', 'Natural plastic surface', 'No plastic']
# 3.png processed for Synthetic material appearance with probability of 1.0
# ['Disconnected components', 'Connected components', 'No components']
# 3.png processed for Floating or disconnected components with probability of 0.8924367
# ['Unnatural materials', 'Realistic materials', 'No material']
# 3.png processed for Inconsistent material properties with probability of 0.6407351
# ['Unnatural depth', 'Natural depth', 'No depth']
# 3.png processed for Depth perception anomalies with probability of 0.99852866
# ['Blurry and sharp areas', 'Consistent sharpness across the image', 'Uniform Resolution']
# 3.png processed for Resolution inconsistencies within regions with probability of 0.5701872
# ['Cut off object', 'Full object', 'No object']
# 3.png processed for Abruptly cut off objects with probability of 0.10627517
# Generating Grad-CAM visualizations: 100%|██████████| 1/1 [00:00<00:00, 39.48it/s]
# Intensity Matrix Shape: (32, 32)
# Min value: 0.0000
# Max value: 1.0000
# Mean value: 0.4184
# ANIMAL DETECTED!!!!!!
# ['Cut off object', 'Full object', 'No object']
# 4.png processed for Abruptly cut off objects with probability of 0.45988047
# ['Unnatural teeth', 'Natural teeth', 'No teeth']
# 4.png processed for Dental anomalies in mammals with probability of 0.9654578
# ['Unnatural paw shape', 'Natural paw shape', 'No paws']
# 4.png processed for Anatomically incorrect paw structures with probability of 0.91561407
# ['Unnatural ear shape', 'Natural ear shape', 'No ears']
# 4.png processed for Misshapen ears or appendages with probability of 0.64471763
# ['Unnatural pose', 'Natural pose', 'Vehicle']
# 4.png processed for Unnatural pose artifacts with probability of 1.0
# ['Asymmetric body', 'Symmetric body', 'Vehicle']
# 4.png processed for Biological asymmetry errors with probability of 0.5889264
# ['Irregular limb size', 'Natural limb size', 'Vehicle']
# 4.png processed for Impossible foreshortening in animal bodies with probability of 0.41134018
# ['Incorrect limb joints', 'Correct limb joints', 'No limb joints']
# 4.png processed for Anatomically impossible joint configurations with probability of 0.0
# ['Asymmetric objects', 'Symmetric objects', 'No object']
# 4.png processed for Asymmetric features in naturally symmetric objects with probability of 0.93373626
# ['Asymmetric face', 'Symmetric face', 'No animal ']
# 4.png processed for Misaligned bilateral elements in animal faces with probability of 0.9897995
# ['Unnatural perspective view', 'Natural perspective view', 'No perspective view']
# 4.png processed for Incorrect perspective rendering with probability of 0.514237
# ['Incorrectly positioned Objects', 'Correctly positioned Objects', 'No object']
# 4.png processed for Spatial relationship errors with probability of 1.0
# ['Different size objects', 'Same size objects', 'Single object']
# 4.png processed for Scale inconsistencies within the same object class with probability of 0.0
# ['Unnatural depth', 'Natural depth', 'No depth']
# 4.png processed for Depth perception anomalies with probability of 0.66557956
# ['Unnatural fur flow', 'Natural fur flow', 'No fur']
# 4.png processed for Improper fur direction flows with probability of 1.0
# ['Unnatural skin colours', 'Natural skin colours', 'No skin']
# 4.png processed for Incorrect skin tones with probability of 0.96819806
# ['Discontinuous Boundaries', 'Continuous Boundaries', 'No Boundaries']
# 4.png processed for Inconsistent object boundaries with probability of 0.58108693
# ['Unnatural sharp edges', 'Natural sharp edges', 'Soft edges']
# 4.png processed for Over-sharpening artifacts with probability of 0.1583221
# ['Over-sharp areas', 'No sharp areas', 'IRRELEVANT']
# 4.png processed for Excessive sharpness in certain image regions with probability of 1.0
# ['Jagged light boundary', 'Smooth light boundary', 'No light boundary']
# 4.png processed for Aliasing along high-contrast edges with probability of 0.1252056
# ['Pixelated, uneven curves', 'Smooth, clean curves', 'Geometric Objects']
# 4.png processed for Jagged edges in curved structures with probability of 1.0
# ['Unnatural depth', 'Natural depth', 'No depth']
# 4.png processed for Fake depth of field with probability of 0.66557956
# ['Unnatural depth', 'Natural depth', 'No depth']
# 4.png processed for Artificial depth of field in object presentation with probability of 0.66557956
# ['Broken and Discontinuous Surfaces', 'Smooth, Realistic Continuous Surfaces', 'No Surfaces']
# 4.png processed for Discontinuous surfaces with probability of 0.0
# ['Unnatural Glossy surface', 'Realistic glossy surface', 'Matte surface']
# 4.png processed for Unnaturally glossy surfaces with probability of 1.0
# ['Unnatural Metallic Reflections', 'Realistic Metallic reflections', 'Metallic Surface']
# 4.png processed for Metallic surface artifacts with probability of 0.5005186
# ['Discontinuous textures', 'Continuous textures', 'IRRELEVANT']
# 4.png processed for Texture bleeding between adjacent regions with probability of 0.43033633
# ['Unnatural Texture repetition patterns', 'Natural Texture Variation', 'Organic Objects']
# 4.png processed for Texture repetition patterns with probability of 0.48376924
# ['Unnatural smooth texture', 'Realistic smooth texture', 'Rough texture']
# 4.png processed for Over-smoothing of natural textures with probability of 0.96042496
# ['Grid patterns', 'No grid patterns', 'No surfaces']
# 4.png processed for Regular grid-like artifacts in textures with probability of 0.0
# ['Unnatural noise in uniform surfaces', 'Natural noise in uniform surfaces', 'No surfaces']
# 4.png processed for Artificial noise patterns in uniform surfaces with probability of 0.5709561
# ['Repeated pattern', 'Unique pattern', 'No pattern']
# 4.png processed for Repeated element patterns with probability of 1.0
# ['Uneven or jarring color patterns', 'Even and natural color distribution', 'Black and white']
# 4.png processed for Systematic color distribution anomalies with probability of 0.47087917
# ['Discontinous colour transition', 'Natural colour transition', 'Black and white']
# 4.png processed for Unnatural color transitions with probability of 0.69620174
# ['Unnatural colour transition', 'Natural colour transition', 'Black and white']
# 4.png processed for Color coherence breaks with probability of 0.7138216
# ['Unnatural patterns in frequencies', 'Natural frequency patterns', 'IRRELEVANT']
# 4.png processed for Frequency domain signatures with probability of 0.52912086
# ['Unnatural smoothness ', 'Natural smoothness', 'Roughness']
# 4.png processed for Artificial smoothness with probability of 1.0
# ['Highly detailed', 'Natural detailed', 'Blur']
# 4.png processed for Exaggerated characteristic features with probability of 0.33333334
# ['Unnatural Plastic surface', 'Natural plastic surface', 'No plastic']
# 4.png processed for Synthetic material appearance with probability of 1.0
# ['Disconnected components', 'Connected components', 'No components']
# 4.png processed for Floating or disconnected components with probability of 0.55708253
# ['Unnatural materials', 'Realistic materials', 'No material']
# 4.png processed for Inconsistent material properties with probability of 0.018996127
# ['Unnatural depth', 'Natural depth', 'No depth']
# 4.png processed for Depth perception anomalies with probability of 0.66557956
# ['Blurry and sharp areas', 'Consistent sharpness across the image', 'Uniform Resolution']
# 4.png processed for Resolution inconsistencies within regions with probability of 0.25592
# ['Cut off object', 'Full object', 'No object']
# 4.png processed for Abruptly cut off objects with probability of 0.45988047
# Generating Grad-CAM visualizations: 100%|██████████| 1/1 [00:00<00:00, 31.81it/s]
# Intensity Matrix Shape: (32, 32)
# Min value: 0.0000
# Max value: 1.0000
# Mean value: 0.1547
# ANIMAL DETECTED!!!!!!
# ['Cut off object', 'Full object', 'No object']
# 8.png processed for Abruptly cut off objects with probability of 0.14205106
# ['Unnatural teeth', 'Natural teeth', 'No teeth']
# 8.png processed for Dental anomalies in mammals with probability of 1.0
# ['Unnatural paw shape', 'Natural paw shape', 'No paws']
# 8.png processed for Anatomically incorrect paw structures with probability of 0.9701229
# ['Unnatural ear shape', 'Natural ear shape', 'No ears']
# 8.png processed for Misshapen ears or appendages with probability of 0.5302915
# ['Unnatural pose', 'Natural pose', 'Vehicle']
# 8.png processed for Unnatural pose artifacts with probability of 1.0
# ['Asymmetric body', 'Symmetric body', 'Vehicle']
# 8.png processed for Biological asymmetry errors with probability of 0.6666667
# ['Irregular limb size', 'Natural limb size', 'Vehicle']
# 8.png processed for Impossible foreshortening in animal bodies with probability of 0.0
# ['Incorrect limb joints', 'Correct limb joints', 'No limb joints']
# 8.png processed for Anatomically impossible joint configurations with probability of 0
# ['Asymmetric objects', 'Symmetric objects', 'No object']
# 8.png processed for Asymmetric features in naturally symmetric objects with probability of 0.99720603
# ['Asymmetric face', 'Symmetric face', 'No animal ']
# 8.png processed for Misaligned bilateral elements in animal faces with probability of 1.0
# ['Unnatural perspective view', 'Natural perspective view', 'No perspective view']
# 8.png processed for Incorrect perspective rendering with probability of 1.0
# ['Incorrectly positioned Objects', 'Correctly positioned Objects', 'No object']
# 8.png processed for Spatial relationship errors with probability of 1.0
# ['Different size objects', 'Same size objects', 'Single object']
# 8.png processed for Scale inconsistencies within the same object class with probability of 0.0
# ['Unnatural depth', 'Natural depth', 'No depth']
# 8.png processed for Depth perception anomalies with probability of 1.0
# ['Unnatural fur flow', 'Natural fur flow', 'No fur']
# 8.png processed for Improper fur direction flows with probability of 1.0
# ['Unnatural skin colours', 'Natural skin colours', 'No skin']
# 8.png processed for Incorrect skin tones with probability of 1.0
# ['Discontinuous Boundaries', 'Continuous Boundaries', 'No Boundaries']
# 8.png processed for Inconsistent object boundaries with probability of 0.9069287
# ['Unnatural sharp edges', 'Natural sharp edges', 'Soft edges']
# 8.png processed for Over-sharpening artifacts with probability of 0.0
# ['Over-sharp areas', 'No sharp areas', 'IRRELEVANT']
# 8.png processed for Excessive sharpness in certain image regions with probability of 1.0
# ['Jagged light boundary', 'Smooth light boundary', 'No light boundary']
# 8.png processed for Aliasing along high-contrast edges with probability of 0.058165766
# ['Pixelated, uneven curves', 'Smooth, clean curves', 'Geometric Objects']
# 8.png processed for Jagged edges in curved structures with probability of 1.0
# ['Unnatural depth', 'Natural depth', 'No depth']
# 8.png processed for Fake depth of field with probability of 1.0
# ['Unnatural depth', 'Natural depth', 'No depth']
# 8.png processed for Artificial depth of field in object presentation with probability of 1.0
# ['Broken and Discontinuous Surfaces', 'Smooth, Realistic Continuous Surfaces', 'No Surfaces']
# 8.png processed for Discontinuous surfaces with probability of 0.0
# ['Unnatural Glossy surface', 'Realistic glossy surface', 'Matte surface']
# 8.png processed for Unnaturally glossy surfaces with probability of 1.0
# ['Unnatural Metallic Reflections', 'Realistic Metallic reflections', 'Metallic Surface']
# 8.png processed for Metallic surface artifacts with probability of 0.853844
# ['Discontinuous textures', 'Continuous textures', 'IRRELEVANT']
# 8.png processed for Texture bleeding between adjacent regions with probability of 0.96141815
# ['Unnatural Texture repetition patterns', 'Natural Texture Variation', 'Organic Objects']
# 8.png processed for Texture repetition patterns with probability of 0.06363134
# ['Unnatural smooth texture', 'Realistic smooth texture', 'Rough texture']
# 8.png processed for Over-smoothing of natural textures with probability of 0.97612673
# ['Grid patterns', 'No grid patterns', 'No surfaces']
# 8.png processed for Regular grid-like artifacts in textures with probability of 0.0
# ['Unnatural noise in uniform surfaces', 'Natural noise in uniform surfaces', 'No surfaces']
# 8.png processed for Artificial noise patterns in uniform surfaces with probability of 0.6382884
# ['Repeated pattern', 'Unique pattern', 'No pattern']
# 8.png processed for Repeated element patterns with probability of 0.9674697
# ['Uneven or jarring color patterns', 'Even and natural color distribution', 'Black and white']
# 8.png processed for Systematic color distribution anomalies with probability of 0.45657206
# ['Discontinous colour transition', 'Natural colour transition', 'Black and white']
# 8.png processed for Unnatural color transitions with probability of 0.9488799
# ['Unnatural colour transition', 'Natural colour transition', 'Black and white']
# 8.png processed for Color coherence breaks with probability of 0.90955913
# ['Unnatural patterns in frequencies', 'Natural frequency patterns', 'IRRELEVANT']
# 8.png processed for Frequency domain signatures with probability of 0.7369399
# ['Unnatural smoothness ', 'Natural smoothness', 'Roughness']
# 8.png processed for Artificial smoothness with probability of 1.0
# ['Highly detailed', 'Natural detailed', 'Blur']
# 8.png processed for Exaggerated characteristic features with probability of 0.0
# ['Unnatural Plastic surface', 'Natural plastic surface', 'No plastic']
# 8.png processed for Synthetic material appearance with probability of 1.0
# ['Disconnected components', 'Connected components', 'No components']
# 8.png processed for Floating or disconnected components with probability of 0.8737713
# ['Unnatural materials', 'Realistic materials', 'No material']
# 8.png processed for Inconsistent material properties with probability of 0.21850997
# ['Unnatural depth', 'Natural depth', 'No depth']
# 8.png processed for Depth perception anomalies with probability of 1.0
# ['Blurry and sharp areas', 'Consistent sharpness across the image', 'Uniform Resolution']
# 8.png processed for Resolution inconsistencies within regions with probability of 0.54619503
# ['Cut off object', 'Full object', 'No object']
# 8.png processed for Abruptly cut off objects with probability of 0.14205106
# Generating Grad-CAM visualizations: 100%|██████████| 1/1 [00:00<00:00, 35.09it/s]
# Intensity Matrix Shape: (32, 32)
# Min value: 0.0000
# Max value: 1.0000
# Mean value: 0.2484
# ANIMAL DETECTED!!!!!!
# ['Cut off object', 'Full object', 'No object']
# 10.png processed for Abruptly cut off objects with probability of 0.41252363
# ['Unnatural teeth', 'Natural teeth', 'No teeth']
# 10.png processed for Dental anomalies in mammals with probability of 0.9815414
# ['Unnatural paw shape', 'Natural paw shape', 'No paws']
# 10.png processed for Anatomically incorrect paw structures with probability of 0.8997904
# ['Unnatural ear shape', 'Natural ear shape', 'No ears']
# 10.png processed for Misshapen ears or appendages with probability of 0.6518868
# ['Unnatural pose', 'Natural pose', 'Vehicle']
# 10.png processed for Unnatural pose artifacts with probability of 1.0
# ['Asymmetric body', 'Symmetric body', 'Vehicle']
# 10.png processed for Biological asymmetry errors with probability of 0.8924481
# ['Irregular limb size', 'Natural limb size', 'Vehicle']
# 10.png processed for Impossible foreshortening in animal bodies with probability of 0.6166391
# ['Incorrect limb joints', 'Correct limb joints', 'No limb joints']
# 10.png processed for Anatomically impossible joint configurations with probability of 0
# ['Asymmetric objects', 'Symmetric objects', 'No object']
# 10.png processed for Asymmetric features in naturally symmetric objects with probability of 0.9719402
# ['Asymmetric face', 'Symmetric face', 'No animal ']
# 10.png processed for Misaligned bilateral elements in animal faces with probability of 0.9768201
# ['Unnatural perspective view', 'Natural perspective view', 'No perspective view']
# 10.png processed for Incorrect perspective rendering with probability of 0.52451295
# ['Incorrectly positioned Objects', 'Correctly positioned Objects', 'No object']
# 10.png processed for Spatial relationship errors with probability of 1.0
# ['Different size objects', 'Same size objects', 'Single object']
# 10.png processed for Scale inconsistencies within the same object class with probability of 0.0
# ['Unnatural depth', 'Natural depth', 'No depth']
# 10.png processed for Depth perception anomalies with probability of 0.91529584
# ['Unnatural fur flow', 'Natural fur flow', 'No fur']
# 10.png processed for Improper fur direction flows with probability of 0.9900562
# ['Unnatural skin colours', 'Natural skin colours', 'No skin']
# 10.png processed for Incorrect skin tones with probability of 1.0
# ['Discontinuous Boundaries', 'Continuous Boundaries', 'No Boundaries']
# 10.png processed for Inconsistent object boundaries with probability of 0.79130113
# ['Unnatural sharp edges', 'Natural sharp edges', 'Soft edges']
# 10.png processed for Over-sharpening artifacts with probability of 0.6469319
# ['Over-sharp areas', 'No sharp areas', 'IRRELEVANT']
# 10.png processed for Excessive sharpness in certain image regions with probability of 1.0
# ['Jagged light boundary', 'Smooth light boundary', 'No light boundary']
# 10.png processed for Aliasing along high-contrast edges with probability of 0.24816196
# ['Pixelated, uneven curves', 'Smooth, clean curves', 'Geometric Objects']
# 10.png processed for Jagged edges in curved structures with probability of 1.0
# ['Unnatural depth', 'Natural depth', 'No depth']
# 10.png processed for Fake depth of field with probability of 0.91529584
# ['Unnatural depth', 'Natural depth', 'No depth']
# 10.png processed for Artificial depth of field in object presentation with probability of 0.91529584
# ['Broken and Discontinuous Surfaces', 'Smooth, Realistic Continuous Surfaces', 'No Surfaces']
# 10.png processed for Discontinuous surfaces with probability of 0.43840948
# ['Unnatural Glossy surface', 'Realistic glossy surface', 'Matte surface']
# 10.png processed for Unnaturally glossy surfaces with probability of 1.0
# ['Unnatural Metallic Reflections', 'Realistic Metallic reflections', 'Metallic Surface']
# 10.png processed for Metallic surface artifacts with probability of 0.37902793
# ['Discontinuous textures', 'Continuous textures', 'IRRELEVANT']
# 10.png processed for Texture bleeding between adjacent regions with probability of 0.79450786
# ['Unnatural Texture repetition patterns', 'Natural Texture Variation', 'Organic Objects']
# 10.png processed for Texture repetition patterns with probability of 0.12717378
# ['Unnatural smooth texture', 'Realistic smooth texture', 'Rough texture']
# 10.png processed for Over-smoothing of natural textures with probability of 0.915447
# ['Grid patterns', 'No grid patterns', 'No surfaces']
# 10.png processed for Regular grid-like artifacts in textures with probability of 0.0
# ['Unnatural noise in uniform surfaces', 'Natural noise in uniform surfaces', 'No surfaces']
# 10.png processed for Artificial noise patterns in uniform surfaces with probability of 0.99679327
# ['Repeated pattern', 'Unique pattern', 'No pattern']
# 10.png processed for Repeated element patterns with probability of 0.65699506
# ['Uneven or jarring color patterns', 'Even and natural color distribution', 'Black and white']
# 10.png processed for Systematic color distribution anomalies with probability of 0.53539777
# ['Discontinous colour transition', 'Natural colour transition', 'Black and white']
# 10.png processed for Unnatural color transitions with probability of 0.8416763
# ['Unnatural colour transition', 'Natural colour transition', 'Black and white']
# 10.png processed for Color coherence breaks with probability of 0.84948707
# ['Unnatural patterns in frequencies', 'Natural frequency patterns', 'IRRELEVANT']
# 10.png processed for Frequency domain signatures with probability of 0.74191767
# ['Unnatural smoothness ', 'Natural smoothness', 'Roughness']
# 10.png processed for Artificial smoothness with probability of 1.0
# ['Highly detailed', 'Natural detailed', 'Blur']
# 10.png processed for Exaggerated characteristic features with probability of 0.0
# ['Unnatural Plastic surface', 'Natural plastic surface', 'No plastic']
# 10.png processed for Synthetic material appearance with probability of 1.0
# ['Disconnected components', 'Connected components', 'No components']
# 10.png processed for Floating or disconnected components with probability of 0.7925896
# ['Unnatural materials', 'Realistic materials', 'No material']
# ...
# 2.png processed for Texture repetition patterns with probability of 0.19569004
# ['Unnatural smooth texture', 'Realistic smooth texture', 'Rough texture']
# 2.png processed for Over-smoothing of natural textures with probability of 0.7260857
# ['Grid patterns', 'No grid patterns', 'No surfaces']
# 2.png processed for Regular grid-like artifacts in textures with probability of 0.0
# ['Unnatural noise in uniform surfaces', 'Natural noise in uniform surfaces', 'No surfaces']
# 2.png processed for Artificial noise patterns in uniform surfaces with probability of 0.72063684
# ['Repeated pattern', 'Unique pattern', 'No pattern']
# 2.png processed for Repeated element patterns with probability of 1.0
# ['Uneven or jarring color patterns', 'Even and natural color distribution', 'Black and white']
# 2.png processed for Systematic color distribution anomalies with probability of 0.43835232
# ['Discontinous colour transition', 'Natural colour transition', 'Black and white']
# 2.png processed for Unnatural color transitions with probability of 0.6963056
# ['Unnatural colour transition', 'Natural colour transition', 'Black and white']
# 2.png processed for Color coherence breaks with probability of 0.76417834
# ['Unnatural patterns in frequencies', 'Natural frequency patterns', 'IRRELEVANT']
# 2.png processed for Frequency domain signatures with probability of 0.65487945
# ['Unnatural smoothness ', 'Natural smoothness', 'Roughness']
# 2.png processed for Artificial smoothness with probability of 1.0
# ['Highly detailed', 'Natural detailed', 'Blur']
# 2.png processed for Exaggerated characteristic features with probability of 0.0
# ['Unnatural Plastic surface', 'Natural plastic surface', 'No plastic']
# 2.png processed for Synthetic material appearance with probability of 1.0
# ['Disconnected components', 'Connected components', 'No components']
# 2.png processed for Floating or disconnected components with probability of 0.90181303
# ['Unnatural materials', 'Realistic materials', 'No material']
# 2.png processed for Inconsistent material properties with probability of 0.0329599
# ['Unnatural depth', 'Natural depth', 'No depth']
# 2.png processed for Depth perception anomalies with probability of 0.9166995
# ['Blurry and sharp areas', 'Consistent sharpness across the image', 'Uniform Resolution']
# 2.png processed for Resolution inconsistencies within regions with probability of 0.25808054
# ['Cut off object', 'Full object', 'No object']
# 2.png processed for Abruptly cut off objects with probability of 0.1409911
# Generating Grad-CAM visualizations: 100%|██████████| 1/1 [00:00<00:00, 30.98it/s]
# Intensity Matrix Shape: (32, 32)
# Min value: 0.0000
# Max value: 0.9723
# Mean value: 0.2908
# ['Unnatural reflections', 'Natural reflections', 'No reflections']
# 5.png processed for Incorrect reflection mapping with probability of 1.0
# ['Cut off object', 'Full object', 'No object']
# 5.png processed for Abruptly cut off objects with probability of 0.22252397
# ['Incorrect mechanical connection', 'Correct mechanical connection', 'No mechanical connection']
# 5.png processed for Impossible mechanical connections with probability of 0.53578985
# ['Unnatural mechanical joints', 'Natural mechanical joints', 'No mechanical joints']
# 5.png processed for Impossible mechanical joints with probability of 0.7785805
# ['Unreal wheels', 'Round wheels', 'No wheels']
# 5.png processed for Incorrect wheel geometry with probability of 0.97633684
# ['Unreal aeroplane', 'Real aeroplane', 'No aeroplane']
# 5.png processed for Implausible aerodynamic structures with probability of 1.0
# ['Panels not aligned properly', 'Panels aligned smoothly', 'Animal']
# 5.png processed for Misaligned body panels with probability of 0.7439598
# ['Incorrect window reflection', 'Correct window reflection', 'No window']
# 5.png processed for Distorted window reflections with probability of 0.9997903
# ['Unnatural Shapes', 'Natural Shapes', 'No Rigid Structures']
# 5.png processed for Non-manifold geometries in rigid structures with probability of 1.0
# ['Irregular sized parts', 'Regular sized parts', 'No Mechanical Parts']
# 5.png processed for Irregular proportions in mechanical components with probability of 0.33023664
# ['Irregular sized parts', 'Regular sized parts', 'No Mechanical Parts']
# 5.png processed for Inconsistent scale of mechanical parts with probability of 0.33023664
# ['Unnatural perspective view', 'Natural perspective view', 'No perspective view']
# 5.png processed for Incorrect perspective rendering with probability of 1.0
# ['Incorrectly positioned Objects', 'Correctly positioned Objects', 'No object']
# 5.png processed for Spatial relationship errors with probability of 1.0
# ['Different size objects', 'Same size objects', 'Single object']
# 5.png processed for Scale inconsistencies within the same object class with probability of 0.0
# ['Unnatural depth', 'Natural depth', 'No depth']
# 5.png processed for Depth perception anomalies with probability of 0.90755004
# ['Unnatural fur flow', 'Natural fur flow', 'No fur']
# 5.png processed for Improper fur direction flows with probability of 1.0
# ['Unnatural skin colours', 'Natural skin colours', 'No skin']
# 5.png processed for Incorrect skin tones with probability of 1.0
# ['Discontinuous Boundaries', 'Continuous Boundaries', 'No Boundaries']
# 5.png processed for Inconsistent object boundaries with probability of 0.3498442
# ['Unnatural sharp edges', 'Natural sharp edges', 'Soft edges']
# 5.png processed for Over-sharpening artifacts with probability of 0.95496446
# ['Over-sharp areas', 'No sharp areas', 'IRRELEVANT']
# 5.png processed for Excessive sharpness in certain image regions with probability of 1.0
# ['Jagged light boundary', 'Smooth light boundary', 'No light boundary']
# 5.png processed for Aliasing along high-contrast edges with probability of 0.3373875
# ['Pixelated, uneven curves', 'Smooth, clean curves', 'Geometric Objects']
# 5.png processed for Jagged edges in curved structures with probability of 1.0
# ['Unnatural depth', 'Natural depth', 'No depth']
# 5.png processed for Fake depth of field with probability of 0.90755004
# ['Unnatural depth', 'Natural depth', 'No depth']
# 5.png processed for Artificial depth of field in object presentation with probability of 0.90755004
# ['Broken and Discontinuous Surfaces', 'Smooth, Realistic Continuous Surfaces', 'No Surfaces']
# 5.png processed for Discontinuous surfaces with probability of 0.44113562
# ['Unnatural Glossy surface', 'Realistic glossy surface', 'Matte surface']
# 5.png processed for Unnaturally glossy surfaces with probability of 1.0
# ['Unnatural Metallic Reflections', 'Realistic Metallic reflections', 'Metallic Surface']
# 5.png processed for Metallic surface artifacts with probability of 1.0
# ['Discontinuous textures', 'Continuous textures', 'IRRELEVANT']
# 5.png processed for Texture bleeding between adjacent regions with probability of 0.85733944
# ['Unnatural Texture repetition patterns', 'Natural Texture Variation', 'Organic Objects']
# 5.png processed for Texture repetition patterns with probability of 0.62837064
# ['Unnatural smooth texture', 'Realistic smooth texture', 'Rough texture']
# 5.png processed for Over-smoothing of natural textures with probability of 0.5821268
# ['Grid patterns', 'No grid patterns', 'No surfaces']
# 5.png processed for Regular grid-like artifacts in textures with probability of 0.0
# ['Unnatural noise in uniform surfaces', 'Natural noise in uniform surfaces', 'No surfaces']
# 5.png processed for Artificial noise patterns in uniform surfaces with probability of 1.0
# ['Repeated pattern', 'Unique pattern', 'No pattern']
# 5.png processed for Repeated element patterns with probability of 0.9840247
# ['Uneven or jarring color patterns', 'Even and natural color distribution', 'Black and white']
# 5.png processed for Systematic color distribution anomalies with probability of 0.6666666
# ['Discontinous colour transition', 'Natural colour transition', 'Black and white']
# 5.png processed for Unnatural color transitions with probability of 0.98983693
# ['Unnatural colour transition', 'Natural colour transition', 'Black and white']
# 5.png processed for Color coherence breaks with probability of 1.0
# ['Unnatural patterns in frequencies', 'Natural frequency patterns', 'IRRELEVANT']
# 5.png processed for Frequency domain signatures with probability of 0.8068572
# ['Unnatural smoothness ', 'Natural smoothness', 'Roughness']
# 5.png processed for Artificial smoothness with probability of 1.0
# ['Highly detailed', 'Natural detailed', 'Blur']
# 5.png processed for Exaggerated characteristic features with probability of 0.0
# ['Unnatural Plastic surface', 'Natural plastic surface', 'No plastic']
# 5.png processed for Synthetic material appearance with probability of 1.0
# ['Disconnected components', 'Connected components', 'No components']
# 5.png processed for Floating or disconnected components with probability of 0.8544084
# ['Unnatural materials', 'Realistic materials', 'No material']
# 5.png processed for Inconsistent material properties with probability of 0.2926752
# ['Unnatural depth', 'Natural depth', 'No depth']
# 5.png processed for Depth perception anomalies with probability of 0.90755004
# ['Blurry and sharp areas', 'Consistent sharpness across the image', 'Uniform Resolution']
# 5.png processed for Resolution inconsistencies within regions with probability of 0.3562302
# ['Cut off object', 'Full object', 'No object']
# 5.png processed for Abruptly cut off objects with probability of 0.22252397
# Generating Grad-CAM visualizations: 100%|██████████| 1/1 [00:00<00:00, 37.78it/s]
# Intensity Matrix Shape: (32, 32)
# Min value: 0.0000
# Max value: 0.9983
# Mean value: 0.2071
# ANIMAL DETECTED!!!!!!
# ['Cut off object', 'Full object', 'No object']
# 6.png processed for Abruptly cut off objects with probability of 0.20642665
# ['Unnatural teeth', 'Natural teeth', 'No teeth']
# 6.png processed for Dental anomalies in mammals with probability of 1.0
# ['Unnatural paw shape', 'Natural paw shape', 'No paws']
# 6.png processed for Anatomically incorrect paw structures with probability of 1.0
# ['Unnatural ear shape', 'Natural ear shape', 'No ears']
# 6.png processed for Misshapen ears or appendages with probability of 0.8862364
# ['Unnatural pose', 'Natural pose', 'Vehicle']
# 6.png processed for Unnatural pose artifacts with probability of 1.0
# ['Asymmetric body', 'Symmetric body', 'Vehicle']
# 6.png processed for Biological asymmetry errors with probability of 0.859739
# ['Irregular limb size', 'Natural limb size', 'Vehicle']
# 6.png processed for Impossible foreshortening in animal bodies with probability of 0.3973929
# ['Incorrect limb joints', 'Correct limb joints', 'No limb joints']
# 6.png processed for Anatomically impossible joint configurations with probability of 0
# ['Asymmetric objects', 'Symmetric objects', 'No object']
# 6.png processed for Asymmetric features in naturally symmetric objects with probability of 1.0
# ['Asymmetric face', 'Symmetric face', 'No animal ']
# 6.png processed for Misaligned bilateral elements in animal faces with probability of 1.0
# ['Unnatural perspective view', 'Natural perspective view', 'No perspective view']
# 6.png processed for Incorrect perspective rendering with probability of 0.9018617
# ['Incorrectly positioned Objects', 'Correctly positioned Objects', 'No object']
# 6.png processed for Spatial relationship errors with probability of 1.0
# ['Different size objects', 'Same size objects', 'Single object']
# 6.png processed for Scale inconsistencies within the same object class with probability of 0.0
# ['Unnatural depth', 'Natural depth', 'No depth']
# 6.png processed for Depth perception anomalies with probability of 0.99409384
# ['Unnatural fur flow', 'Natural fur flow', 'No fur']
# 6.png processed for Improper fur direction flows with probability of 1.0
# ['Unnatural skin colours', 'Natural skin colours', 'No skin']
# 6.png processed for Incorrect skin tones with probability of 1.0
# ['Discontinuous Boundaries', 'Continuous Boundaries', 'No Boundaries']
# 6.png processed for Inconsistent object boundaries with probability of 0.9633151
# ['Unnatural sharp edges', 'Natural sharp edges', 'Soft edges']
# 6.png processed for Over-sharpening artifacts with probability of 1.0000008
# ['Over-sharp areas', 'No sharp areas', 'IRRELEVANT']
# 6.png processed for Excessive sharpness in certain image regions with probability of 1.0
# ['Jagged light boundary', 'Smooth light boundary', 'No light boundary']
# 6.png processed for Aliasing along high-contrast edges with probability of 0.14238037
# ['Pixelated, uneven curves', 'Smooth, clean curves', 'Geometric Objects']
# 6.png processed for Jagged edges in curved structures with probability of 1.0
# ['Unnatural depth', 'Natural depth', 'No depth']
# 6.png processed for Fake depth of field with probability of 0.99409384
# ['Unnatural depth', 'Natural depth', 'No depth']
# 6.png processed for Artificial depth of field in object presentation with probability of 0.99409384
# ['Broken and Discontinuous Surfaces', 'Smooth, Realistic Continuous Surfaces', 'No Surfaces']
# 6.png processed for Discontinuous surfaces with probability of 0.15514578
# ['Unnatural Glossy surface', 'Realistic glossy surface', 'Matte surface']
# 6.png processed for Unnaturally glossy surfaces with probability of 1.0
# ['Unnatural Metallic Reflections', 'Realistic Metallic reflections', 'Metallic Surface']
# 6.png processed for Metallic surface artifacts with probability of 0.62754
# ['Discontinuous textures', 'Continuous textures', 'IRRELEVANT']
# 6.png processed for Texture bleeding between adjacent regions with probability of 0.9042953
# ['Unnatural Texture repetition patterns', 'Natural Texture Variation', 'Organic Objects']
# 6.png processed for Texture repetition patterns with probability of 0.0
# ['Unnatural smooth texture', 'Realistic smooth texture', 'Rough texture']
# 6.png processed for Over-smoothing of natural textures with probability of 1.0
# ['Grid patterns', 'No grid patterns', 'No surfaces']
# 6.png processed for Regular grid-like artifacts in textures with probability of 0.0
# ['Unnatural noise in uniform surfaces', 'Natural noise in uniform surfaces', 'No surfaces']
# 6.png processed for Artificial noise patterns in uniform surfaces with probability of 1.0
# ['Repeated pattern', 'Unique pattern', 'No pattern']
# 6.png processed for Repeated element patterns with probability of 1.0
# ['Uneven or jarring color patterns', 'Even and natural color distribution', 'Black and white']
# 6.png processed for Systematic color distribution anomalies with probability of 0.9917683
# ['Discontinous colour transition', 'Natural colour transition', 'Black and white']
# 6.png processed for Unnatural color transitions with probability of 0.9875914
# ['Unnatural colour transition', 'Natural colour transition', 'Black and white']
# 6.png processed for Color coherence breaks with probability of 1.0
# ['Unnatural patterns in frequencies', 'Natural frequency patterns', 'IRRELEVANT']
# 6.png processed for Frequency domain signatures with probability of 0.9449727
# ['Unnatural smoothness ', 'Natural smoothness', 'Roughness']
# 6.png processed for Artificial smoothness with probability of 1.0
# ['Highly detailed', 'Natural detailed', 'Blur']
# 6.png processed for Exaggerated characteristic features with probability of 0.0
# ['Unnatural Plastic surface', 'Natural plastic surface', 'No plastic']
# 6.png processed for Synthetic material appearance with probability of 1.0
# ['Disconnected components', 'Connected components', 'No components']
# 6.png processed for Floating or disconnected components with probability of 0.43302143
# ['Unnatural materials', 'Realistic materials', 'No material']
# 6.png processed for Inconsistent material properties with probability of 0.6786848
# ['Unnatural depth', 'Natural depth', 'No depth']
# 6.png processed for Depth perception anomalies with probability of 0.99409384
# ['Blurry and sharp areas', 'Consistent sharpness across the image', 'Uniform Resolution']
# 6.png processed for Resolution inconsistencies within regions with probability of 0.56843185
# ['Cut off object', 'Full object', 'No object']
# 6.png processed for Abruptly cut off objects with probability of 0.20642665
